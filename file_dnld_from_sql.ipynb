# %%
from dotenv import load_dotenv
import os

# %%
import mysql.connector as connection
import pandas as pd

# %%
load_dotenv('env/.env')
# Out:
# True

# %%
host=os.environ.get("host")
username = os.environ.get("username")
password = os.environ.get("password")
port = os.environ.get("port")
database = os.environ.get("database")
query="SELECT * FROM colas_sharing.form_display;"
try:
    mydb = connection.connect(host=host, database = database,user=username, passwd=password,use_pure=True)
    result_dataFrame = pd.read_sql(query,mydb)
    mydb.close() #close the connection
except Exception as e:
    mydb.close()
    print(str(e))

# result_dataFrame = pd.read_sql(query, mydb)
# Out:
# /home/ashiktonmoy/Desktop/Winesfere_ocr/venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
result_dataFrame
# Out:
#               ttb_id  ct origin rep_id source_of_product  \
# 0     10002001000002  81     02                 Domestic
# 1     10004001000231  88     38                 Domestic
# 2     10006001000031  80     70                 Imported
# 3     10008001000116  81     53                 Imported
# 4     10011001000137  80     50                 Imported
# ...              ...  ..    ...    ...               ...
# 1722  14233001000224  88     01                 Domestic
# 1723  14233001000254  88     51                 Imported
# 1724  14239001000236  88     01                 Domestic
# 1725  14240001000113  81     52                 Imported
# 1726  14241001000312  84     01                 Domestic
#
#                                                 address type_of_product  \
# 0     VALERIE BATEMAN\n11 MOUNTAIN VIEW ESTATESRDWIN...            Wine
# 1     WILLAMETTE VALLEY VINEYARDS, WILLAMETTE VALLEY...            Wine
# 2     INNOVINO INTERNATIONAL INC\n7707 N UNIVERSITY ...            Wine
# 3     VALCKENBERG INTERNATIONAL, INC.\n8153 E 44TH S...            Wine
# 4     SANTA ARMOSA, LLC\n136 SPEEDWELL AVEMORRISTOWN...            Wine
# ...                                                 ...             ...
# 1722  TREASURY WINE ESTATES AMERICAS COMPANY\n1250 C...            Wine
# 1723  WINEBOW, BOSTON WINE COMPANY, LTD.\n30 DANE ST...            Wine
# 1724  FREE FLOW WINES, FREE FLOW WINES, LLC\n2557 NA...            Wine
# 1725  VINE PRO IMPORTS, LLC\n7535 W 24TH AVE , # S-1...            Wine
# 1726  RB WINE ASSOCIATES, LLC\n499MOORE LNHEALDSBURG...            Wine
#
#      mailing_address email formula_sop_no  ...  \
# 0                                          ...
# 1                                          ...
# 2                                          ...
# 3                                          ...
# 4                                          ...
# ...              ...   ...            ...  ...
# 1722                                       ...
# 1723                                       ...
# 1724                                       ...
# 1725                                       ...
# 1726                                       ...
#
#                   wine_application_if_on_label wine_vintage_date_if_on_label  \
# 0                               NEW YORK STATE                          2008
# 1                            WILLAMETTE VALLEY                          2007
# 2                               CENTRAL VALLEY                          2008
# 3                                        MOSEL                          2007
# 4     SALENTO\r\nINDICAZIONE GEOGRAFICA TIPICA                          2008
# ...                                        ...                           ...
# 1722                                  OAKVILLE                          2012
# 1723                                     MEDOC                          2009
# 1724                             SONOMA VALLEY                          2013
# 1725      VINO DE LA TIERRA DE CASTILLA Y LEON                          2012
# 1726                             SONOMA COUNTY
#
#         phone_number      fax_number date_of_application  \
# 0     (518) 734-5214  (518) 734-5214          2010-01-02
# 1     (503) 588-9463                          2010-01-04
# 2     (305) 505-6205  (954) 839-6495          2010-01-06
# 3     (815) 404-6224                          2010-01-08
# 4     (866) 709-7289                          2010-01-11
# ...              ...             ...                 ...
# 1722  (707) 299-3142                          2014-08-21
# 1723  (201) 930-2392  (201) 930-2413          2014-08-21
# 1724  (415) 626-1215  (415) 373-3925          2014-08-27
# 1725  (786) 546-0551                          2014-08-28
# 1726  (707) 433-8400                          2014-08-29
#
#      print_name_of_applicant date_issued    status  \
# 0            VALERIE BATEMAN  2010-01-06  APPROVED
# 1               JAMES BERNAU  2010-01-05  APPROVED
# 2              DANIELLE HALL  2010-01-07  APPROVED
# 3            NATALIE RANDALL  2010-01-11  APPROVED
# 4                  GAL KEREN  2010-01-15  APPROVED
# ...                      ...         ...       ...
# 1722           Sarah Spiller  2014-09-13  APPROVED
# 1723      PATRICIA PATTERSON  2014-09-15  APPROVED
# 1724             TRACY KASIN  2014-09-16  APPROVED
# 1725        Tiffany Gonzalez  2014-09-24  APPROVED
# 1726           REBECCA FAUST  2014-09-17  APPROVED
#
#                                                img_data         inserted_at
# 0     [{"img": "cola_images/Chardonnay_VSR2008.jpg",... 2022-05-25 14:57:25
# 1     [{"img": "cola_images/CHV_2007_pn_b_2_72x3_58_... 2022-05-25 16:35:25
# 2     [{"img": "cola_images/vina_d_iela_CAB_RES_bran... 2022-05-25 16:40:28
# 3     [{"img": "cola_images/JJ4-07M.jpg", "text": "I... 2022-05-25 16:49:23
# 4     [{"img": "cola_images/NeroDiMoinsignoreFinale.... 2022-05-25 16:54:47
# ...                                                 ...                 ...
# 1722  [{"img": "cola_images/2012_ETU_Vine_Hill_CabS_... 2022-05-31 15:18:56
# 1723  [{"img": "cola_images/Goulee_front_1.jpg", "te... 2022-05-31 15:17:30
# 1724  [{"img": "cola_images/2013_Custard_CH.jpg", "t... 2022-05-31 15:42:01
# 1725  [{"img": "cola_images/PLwhiteFrontNEW.JPG", "t... 2022-05-31 15:45:59
# 1726  [{"img": "cola_images/2012_M_S_Rose_Son_Co_Fro... 2022-05-31 15:49:02
#
# [1727 rows x 24 columns]

# %%
result_dataFrame.head()
# Out:
#            ttb_id  ct origin rep_id source_of_product  \
# 0  10002001000002  81     02                 Domestic
# 1  10004001000231  88     38                 Domestic
# 2  10006001000031  80     70                 Imported
# 3  10008001000116  81     53                 Imported
# 4  10011001000137  80     50                 Imported
#
#                                              address type_of_product  \
# 0  VALERIE BATEMAN\n11 MOUNTAIN VIEW ESTATESRDWIN...            Wine
# 1  WILLAMETTE VALLEY VINEYARDS, WILLAMETTE VALLEY...            Wine
# 2  INNOVINO INTERNATIONAL INC\n7707 N UNIVERSITY ...            Wine
# 3  VALCKENBERG INTERNATIONAL, INC.\n8153 E 44TH S...            Wine
# 4  SANTA ARMOSA, LLC\n136 SPEEDWELL AVEMORRISTOWN...            Wine
#
#   mailing_address email formula_sop_no  ...  \
# 0                                       ...
# 1                                       ...
# 2                                       ...
# 3                                       ...
# 4                                       ...
#
#                wine_application_if_on_label wine_vintage_date_if_on_label  \
# 0                            NEW YORK STATE                          2008
# 1                         WILLAMETTE VALLEY                          2007
# 2                            CENTRAL VALLEY                          2008
# 3                                     MOSEL                          2007
# 4  SALENTO\r\nINDICAZIONE GEOGRAFICA TIPICA                          2008
#
#      phone_number      fax_number date_of_application print_name_of_applicant  \
# 0  (518) 734-5214  (518) 734-5214          2010-01-02         VALERIE BATEMAN
# 1  (503) 588-9463                          2010-01-04            JAMES BERNAU
# 2  (305) 505-6205  (954) 839-6495          2010-01-06           DANIELLE HALL
# 3  (815) 404-6224                          2010-01-08         NATALIE RANDALL
# 4  (866) 709-7289                          2010-01-11               GAL KEREN
#
#   date_issued    status                                           img_data  \
# 0  2010-01-06  APPROVED  [{"img": "cola_images/Chardonnay_VSR2008.jpg",...
# 1  2010-01-05  APPROVED  [{"img": "cola_images/CHV_2007_pn_b_2_72x3_58_...
# 2  2010-01-07  APPROVED  [{"img": "cola_images/vina_d_iela_CAB_RES_bran...
# 3  2010-01-11  APPROVED  [{"img": "cola_images/JJ4-07M.jpg", "text": "I...
# 4  2010-01-15  APPROVED  [{"img": "cola_images/NeroDiMoinsignoreFinale....
#
#           inserted_at
# 0 2022-05-25 14:57:25
# 1 2022-05-25 16:35:25
# 2 2022-05-25 16:40:28
# 3 2022-05-25 16:49:23
# 4 2022-05-25 16:54:47
#
# [5 rows x 24 columns]

# %%
result_dataFrame.to_csv('data/colas_sharing.form_display.csv')

# %%
result_dataFrame.to_excel('data/colas_sharing_form_display.xlsx')
